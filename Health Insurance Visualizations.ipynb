# %%
import pandas as pd
import seaborn as sns
import numpy as np


df = pd.read_excel(r"C:\Users\jesse\OneDrive\Desktop\Health Insurance Dataset.xlsx")

# %%
display(df)
# Out:
#       Age     Sex     BMI  Children Smoker     Region      Charges Level  \
# 0      19  female  27.900         0    yes  southwest  16884.92400     B
# 1      18    male  33.770         1     no  southeast   1725.55230     C
# 2      28    male  33.000         3     no  southeast   4449.46200     B
# 3      33    male  22.705         0     no  northwest  21984.47061     A
# 4      32    male  28.880         0     no  northwest   3866.85520     C
# ...   ...     ...     ...       ...    ...        ...          ...   ...
# 1333   50    male  30.970         3     no  northwest  10600.54830     B
# 1334   18  female  31.920         0     no  northeast   2205.98080     C
# 1335   18  female  36.850         0     no  southeast   1629.83350     B
# 1336   21  female  25.800         0     no  southwest   2007.94500     D
# 1337   61  female  29.070         0    yes  northwest  29141.36030     C
#
#       Score
# 0        72
# 1        69
# 2        90
# 3        47
# 4        76
# ...

# %%
sns.displot(data=df["Score"])

# %%
sns.displot(data=df["BMI"], kind="kde")

# %%
df["BMI"].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: BMI, dtype: float64

# %%
sns.displot(df["Charges"], kind="kde")

# %%
df["Charges"].describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: Charges, dtype: float64

# %%
sns.displot(df["Smoker"])

# %%
df["Smoker"].describe()
# Out:
# count     1338
# unique       2
# top         no
# freq      1064
# Name: Smoker, dtype: object

# %%
df["Smoker"].value_counts()
# Out:
# Smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
sns.displot(df["Sex"], color="Green")

# %%
df["Sex"].describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: Sex, dtype: object

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
 
df.plot(x = 'BMI', y = 'Charges', kind = 'scatter');
plt.show()

# %%
df["Charges"].corr(df["BMI"])
# Out:
# 0.19834096883362892

# %%
import seaborn.objects as so

so.Plot(df, x="Region", color="Level").add(so.Bar(), so.Hist())
